# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import seaborn as sns

# %% [markdown]
# ##  Load data

# %%
movies_df = pd.read_csv("./IMDB-Movie-Data.csv",delimiter=",")

# %%
movies_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## Inspect Data

# %%
movies_df.shape
# Out:
# (1000, 12)

# %%
#The last five infor at the end of the data
movies_df.tail(5)
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
#The first five info at the top of the data
movies_df.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#Information on all Data
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# ## Handle Duplicate Data

# %%
# Check for length of data
print("The lenght of data before dropping duplicate:", len(movies_df))
# Out:
# The lenght of data before dropping duplicate: 1000

# %%
remove_duplicate_df = movies_df.drop_duplicates()
print("The lenght of data before dropping duplicate:", len(remove_duplicate_df))

# No duplicate
# Out:
# The lenght of data before dropping duplicate: 1000

# %% [markdown]
# ## Renaming Column

# %%
movies_df.columns
movies_df.rename(columns={
    "Runtime (Minutes)": "Runtime",
    "Revenue (Millions)": "Revenue"
},inplace=True)

# %%
movies_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# Sum of rows with null values
movies_df.isnull().sum()
# Out:
# Rank             0
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        128
# Metascore       64
# dtype: int64

# %% [markdown]
# ## Replacing missing values with mean

# %%
# Calculate the mean of the revenue column
avg_revenue = np.round(movies_df.Revenue.mean(),2)
avg_revenue
# Out:
# 82.96

# %%
#fill the missing data in the revue with avg_revenue(fillna means not available)
movies_df.Revenue.fillna(avg_revenue, inplace=True)

# %%
avg_metascore = np.round(movies_df.Metascore.mean(),2)

movies_df.Metascore.fillna(avg_metascore, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank           0
# Title          0
# Genre          0
# Description    0
# Director       0
# Actors         0
# Year           0
# Runtime        0
# Rating         0
# Votes          0
# Revenue        0
# Metascore      0
# dtype: int64

# %% [markdown]
# ## check correlation of continous variable

# %%
movies_df.corr()
# Out:
#                Rank      Year   Runtime    Rating     Votes   Revenue  \
# Rank       1.000000 -0.261605 -0.221739 -0.219555 -0.283876 -0.252995
# Year      -0.261605  1.000000 -0.164900 -0.211219 -0.411904 -0.117558
# Runtime   -0.221739 -0.164900  1.000000  0.392214  0.407062  0.247831
# Rating    -0.219555 -0.211219  0.392214  1.000000  0.511537  0.189524
# Votes     -0.283876 -0.411904  0.407062  0.511537  1.000000  0.607937
# Revenue   -0.252995 -0.117558  0.247831  0.189524  0.607937  1.000000
# Metascore -0.185157 -0.076076  0.202238  0.604721  0.318108  0.132299
#
#            Metascore
# Rank       -0.185157
# Year       -0.076076
# Runtime     0.202238
# Rating      0.604721
# Votes       0.318108
# Revenue     0.132299
# Metascore   1.000000

# %% [markdown]
# ## Define a column: Rating Category

# %%
# define rating functions
def define_rating(x):
    if x >=8.0:
        return "Excellent"
    elif x >= 4.0 and x < 8.0:
        return "Good"
    else:
        return "Poor"

# %%
# apply function to rating column
movies_df["Rating Category"] = movies_df["Rating"].apply(define_rating)

# %%
movies_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
x = movies_df.Votes
y = movies_df.Revenue

plt.scatter(x,y, c="r", marker="*")
plt.title("Relationship between Votes and Revenue")
plt.xlabel("Number of Votes")
plt.ylabel("Revenue")

plt.show()

# %%
rating = movies_df["Rating"]
plt.hist(rating)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #Analysis
# 1.In what year is the highest revenue genarated

# %%
revenue = movies_df.Year
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = movies_df.groupby(["Year"])["Revenue"].sum().plot(kind="bar")

# %%
revenue_by_year=movies_df.groupby(["Year"], as_index=False)["Revenue"].sum().sort_values(by="Year", ascending=False)
sns.barplot(y = "Revenue",x = "Year", data=revenue_by_year)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Revenue'>

# %%
sns.lineplot(x="Year",y="Revenue", data=revenue_by_year);

# %%
## 2. revenue generated by each genre
revenue_by_genre = movies_df.groupby(["Genre"])["Revenue"].sum().plot(kind="bar")

# %%
#total revenue generated by each directors
revenue_by_director = movies_df.groupby(["Director"])["Revenue"].sum().plot(kind="bar")

# %%
#Rating Categories
movies_by_rating = movies_df.groupby(["Rating Category"], as_index=False)["Title"].count()
sns.barplot(x= "Rating Category",y = "Title", data=movies_by_rating)
# Out:
# <AxesSubplot:xlabel='Rating Category', ylabel='Title'>
